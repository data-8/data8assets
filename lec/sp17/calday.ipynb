# %%
# Run this and then delete it

from datascience import *
import numpy as np

import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
# %matplotlib inline

# %%
2 + 3
# Out:
# 5

# %%
2 * 3
# Out:
# 6

# %%
1 + 2 * (3 * 4 * 5 // 6) ** 3 + 7 + 8 - 9 + 10
# Out:
# 2017

# %%
t = Table.read_table('little_women_chapters.csv')
t
# Out:
# Chapter | Periods | Characters
# 1       | 189     | 21759
# 2       | 188     | 22148
# 3       | 231     | 20558
# 4       | 195     | 25526
# 5       | 255     | 23395
# 6       | 140     | 14622
# 7       | 131     | 14431
# 8       | 214     | 22476
# 9       | 337     | 33767
# 10      | 185     | 18508
# ... (37 rows omitted)

# %%
t.scatter(1, 2)

# %%
def draw_line(a, b):
    x = np.array([50, 450])
    y = a * x + b
    
    t.scatter(1, 2)
    plots.plot(x, y)

# %%
draw_line(140, 0)

# %%
def draw_line(a, b):
    x = np.array([50, 450])
    y = a * x + b
    
    t.scatter(1, 2)
    plots.plot(x, y)
    
    # Add these two lines in your clipboard in advance!
    for _, x, y in t.rows:
        plots.plot([x, x], [y, a * x + b], color='r', lw=0.5)

# %%
draw_line(140, 0)

# %%
draw_line(80, 0)

# %%
draw_line(80, 5000)

# %%
def average_squared_distance(a, b):
    x = t.column(1)
    y = t.column(2)
    fitted = a * x + b
    return np.average((y - fitted) ** 2) / 1e6

# %%
average_squared_distance(140, 0)
# Out:
# 54.081190936170216

# %%
average_squared_distance(80, 0)
# Out:
# 44.82963008510638

# %%
average_squared_distance(80, 5000)
# Out:
# 8.7883534893617021

# %%
minimize(average_squared_distance)
# Out:
# array([   86.97784106,  4744.78483438])

# %%
draw_line(86.97784106,  4744.78483438)

# %%
t
# Out:
# Chapter | Periods | Characters
# 1       | 189     | 21759
# 2       | 188     | 22148
# 3       | 231     | 20558
# 4       | 195     | 25526
# 5       | 255     | 23395
# 6       | 140     | 14622
# 7       | 131     | 14431
# 8       | 214     | 22476
# 9       | 337     | 33767
# 10      | 185     | 18508
# ... (37 rows omitted)

# %%
t.where('Periods', are.below(180))
# Out:
# Chapter | Periods | Characters
# 6       | 140     | 14622
# 7       | 131     | 14431
# 13      | 175     | 18669
# 16      | 172     | 15353
# 17      | 155     | 13879
# 18      | 144     | 17432
# 19      | 121     | 17338
# 20      | 145     | 14252
# 22      | 120     | 13708
# 25      | 91      | 13526
# ... (9 rows omitted)

# %%
are.below(180)(45)
# Out:
# True

# %%
t['Periods'] + 1
# Out:
# array([190, 189, 232, 196, 256, 141, 132, 215, 338, 186, 194, 430, 176,
#        181, 182, 173, 156, 145, 122, 146, 270, 121, 248, 183,  92, 151,
#        110, 272, 234, 219, 179, 225, 233, 258, 202, 101, 158, 207, 264,
#         62, 188, 119, 306,  96,  97, 235, 393])
