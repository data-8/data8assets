# %%
import numpy as np
from datascience import *
# %matplotlib inline
np.set_printoptions(threshold=50)

# %% [markdown]
# ## Review

# %%
# This table can be found online: https://www.statcrunch.com/app/index.php?dataid=1843341
nba = Table.read_table('http://inferentialthinking.com/notebooks/nba_salaries.csv').relabeled(3, 'SALARY').drop(2)
nba
# Out:
# PLAYER           | POSITION | SALARY
# Paul Millsap     | PF       | 18.6717
# Al Horford       | C        | 12
# Tiago Splitter   | C        | 9.75625
# Jeff Teague      | PG       | 8
# Kyle Korver      | SG       | 5.74648
# Thabo Sefolosha  | SF       | 4
# Mike Scott       | PF       | 3.33333
# Kent Bazemore    | SF       | 2
# Dennis Schroder  | PG       | 1.7634
# Tim Hardaway Jr. | SG       | 1.30452
# ... (407 rows omitted)

# %%
nba.where(1, 'PG').where(2, are.above(15)).column(0)
# Out:
# array(['Derrick Rose', 'Kyrie Irving', 'Chris Paul', 'Russell Westbrook',
#        'John Wall'],
#       dtype='<U24')

# %%
nba.with_row(['DeNero', 'C', 0.0])
nba.where('PLAYER', are.containing('DeNero'))
# Out:
# PLAYER | POSITION | SALARY

# %%
sorted_by_salary = nba.where('POSITION', 'C').sort('SALARY')
sorted_by_salary.take([2, 3, 4]).column(0)
# Out:
# array(['Jeff Withey', 'Robert Sacre', 'Walter Tavares'],
#       dtype='<U24')

# %% [markdown]
# ## Population & Age

# %%
# As of Jan 2017, this census file is online here: 
data = 'http://www2.census.gov/programs-surveys/popest/datasets/2010-2015/national/asrh/nc-est2015-agesex-res.csv'

# A copy can be accessed here in case census.gov moves the file:
# data = 'http://inferentialthinking.com/notebooks/nc-est2015-agesex-res.csv'

full_census_table = Table.read_table(data)
full_census_table
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-2176dedbb155> in <module>()
#       5 # data = 'http://inferentialthinking.com/notebooks/nc-est2015-agesex-res.csv'
#       6
# ----> 7 full_census_table = Table.read_table(data)
#       8 full_census_table
#
# /Users/denero/Documents/workspace/d8/datascience/datascience/tables.py in read_table(cls, filepath_or_buffer, *args, **vargs)
#     130         except AttributeError:
#     131             pass
# --> 132         df = pandas.read_table(filepath_or_buffer, *args, **vargs)
#     133         return cls.from_df(df)
#     134
#
# /Users/denero/anaconda/envs/site/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /Users/denero/anaconda/envs/site/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     373     filepath_or_buffer, _, compression = get_filepath_or_buffer(
#     374         filepath_or_buffer, encoding,
# --> 375         compression=kwds.get('compression', None))
#     376     kwds['compression'] = (inferred_compression if compression == 'infer'
#     377                            else compression)
#
# /Users/denero/anaconda/envs/site/lib/python3.5/site-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     236
#     237     if _is_url(filepath_or_buffer):
# --> 238         req = _urlopen(str(filepath_or_buffer))
#     239         if compression == 'infer':
#     240             content_encoding = req.headers.get('Content-Encoding', None)
#
# /Users/denero/anaconda/envs/site/lib/python3.5/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# /Users/denero/anaconda/envs/site/lib/python3.5/urllib/request.py in open(self, fullurl, data, timeout)
#     470         for processor in self.process_response.get(protocol, []):
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#     474         return response
#
# /Users/denero/anaconda/envs/site/lib/python3.5/urllib/request.py in http_response(self, request, response)
#     580         if not (200 <= code < 300):
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#     584         return response
#
# /Users/denero/anaconda/envs/site/lib/python3.5/urllib/request.py in error(self, proto, *args)
#     508         if http_err:
#     509             args = (dict, 'default', 'http_error_default') + orig_args
# --> 510             return self._call_chain(*args)
#     511
#     512 # XXX probably also want an abstract factory that knows when it makes
#
# /Users/denero/anaconda/envs/site/lib/python3.5/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# /Users/denero/anaconda/envs/site/lib/python3.5/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     588 class HTTPDefaultErrorHandler(BaseHandler):
#     589     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 590         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     591
#     592 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 403: Forbidden

# %%
partial = full_census_table.select('SEX', 'AGE', 'POPESTIMATE2010', 'POPESTIMATE2015')
partial

# %%
us_pop = partial.relabeled(2, '2010').relabeled(3, '2015')
us_pop

# %%
us_pop.column('2015') - us_pop.column('2010')

# %%
change = us_pop.column('2015') - us_pop.column('2010')
census = us_pop.with_columns(
    'Change', change,
    'Percent Change', change/us_pop.column('2010')
)
census.set_format('Percent Change', PercentFormatter)

# %%
census.sort('Change', descending=True)

# %%
(321418820/309346863) ** (1/5) - 1

# %%
everyone = census.sort('Change', descending=True).row(0)
everyone

# %%
type(everyone)

# %%
(everyone.item(3)/everyone.item(2)) ** (1/5) - 1

# %%
five_year_rate = everyone.item(5)
(five_year_rate + 1) ** (1/5) - 1

# %%
2010-68 # Bombing of Pearl Harbor was 12/7/1941

# %%
2015-68 # Bombing of Nagasaki was 8/9/1945

# %% [markdown]
# ## Population & Gender

# %%
us_pop.where('AGE', are.above(97)).show()

# %%
us_pop_2015 = us_pop.drop('2010')
all_ages = us_pop_2015.where('AGE', are.equal_to(999))
all_ages

# %%
all_ages.column('2015').item(0)

# %%
all_ages.with_column(
    'Proportion', all_ages.column('2015')/all_ages.column('2015').item(0)
).set_format('Proportion', PercentFormatter)

# %%
infants = us_pop_2015.where('AGE', are.equal_to(0))
infants

# %%
infants.with_column(
    'Proportion', infants.column('2015')/infants.column('2015').item(0)
).set_format('Proportion', PercentFormatter)

# %%
females_all_rows = us_pop_2015.where('SEX', are.equal_to(2))
females = females_all_rows.where('AGE', are.not_equal_to(999))
females

# %%
males_all_rows = us_pop_2015.where('SEX', are.equal_to(1))
males = males_all_rows.where('AGE', are.not_equal_to(999))
males

# %%
males.column('AGE')

# %%
females.column('AGE')

# %%
ratios = Table().with_columns(
    'AGE', females.column('AGE'),
    '2015 F:M RATIO', females.column('2015')/males.column('2015')
)
ratios

# %%
ratios.where('AGE', are.above(75)).show()

# %%
ratios.plot('AGE')
