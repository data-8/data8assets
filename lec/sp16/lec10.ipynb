# %%
import numpy as np
from datascience import *

# Configure notebook (happens automatically on data8.berkeley.edu)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# Configure for presentation
np.set_printoptions(threshold=50, linewidth=50)
import matplotlib as mpl
mpl.rc('font', size=16)

# %%
top = Table.read_table('top_movies.csv')
top.set_format([2, 3], NumberFormatter).show(30)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Title</th> <th>Studio</th> <th>Gross</th> <th>Gross (Adjusted)</th> <th>Year</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Star Wars: The Force Awakens                 </td> <td>Buena Vista (Disney)</td> <td>906,723,418</td> <td>906,723,400     </td> <td>2015</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Avatar                                       </td> <td>Fox                 </td> <td>760,507,625</td> <td>846,120,800     </td> <td>2009</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Titanic                                      </td> <td>Paramount           </td> <td>658,672,302</td> <td>1,178,627,900   </td> <td>1997</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Jurassic World                               </td> <td>Universal           </td> <td>652,270,625</td> <td>687,728,000     </td> <td>2015</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Marvel's The Avengers                        </td> <td>Buena Vista (Disney)</td> <td>623,357,910</td> <td>668,866,600     </td> <td>2012</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>The Dark Knight                              </td> <td>Warner Bros.        </td> <td>534,858,444</td> <td>647,761,600     </td> <td>2008</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Star Wars: Episode I - The Phantom Menace    </td> <td>Fox                 </td> <td>474,544,677</td> <td>785,715,000     </td> <td>1999</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Star Wars                                    </td> <td>Fox                 </td> <td>460,998,007</td> <td>1,549,640,500   </td> <td>1977</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Avengers: Age of Ultron                      </td> <td>Buena Vista (Disney)</td> <td>459,005,868</td> <td>465,684,200     </td> <td>2015</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>The Dark Knight Rises                        </td> <td>Warner Bros.        </td> <td>448,139,099</td> <td>500,961,700     </td> <td>2012</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Shrek 2                                      </td> <td>Dreamworks          </td> <td>441,226,247</td> <td>618,143,100     </td> <td>2004</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>E.T.: The Extra-Terrestrial                  </td> <td>Universal           </td> <td>435,110,554</td> <td>1,234,132,700   </td> <td>1982</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>The Hunger Games: Catching Fire              </td> <td>Lionsgate           </td> <td>424,668,047</td> <td>444,697,400     </td> <td>2013</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Pirates of the Caribbean: Dead Man's Chest   </td> <td>Buena Vista (Disney)</td> <td>423,315,812</td> <td>562,266,800     </td> <td>2006</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>The Lion King                                </td> <td>Buena Vista (Disney)</td> <td>422,783,777</td> <td>775,573,900     </td> <td>1994</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Toy Story 3                                  </td> <td>Buena Vista (Disney)</td> <td>415,004,880</td> <td>454,156,300     </td> <td>2010</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Iron Man 3                                   </td> <td>Buena Vista (Disney)</td> <td>409,013,994</td> <td>424,632,700     </td> <td>2013</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>The Hunger Games                             </td> <td>Lionsgate           </td> <td>408,010,692</td> <td>442,510,400     </td> <td>2012</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Spider-Man                                   </td> <td>Sony                </td> <td>403,706,375</td> <td>604,517,300     </td> <td>2002</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Jurassic Park                                </td> <td>Universal           </td> <td>402,453,882</td> <td>799,721,000     </td> <td>1993</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Transformers: Revenge of the Fallen          </td> <td>Paramount/Dreamworks</td> <td>402,111,870</td> <td>468,938,100     </td> <td>2009</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Frozen                                       </td> <td>Buena Vista (Disney)</td> <td>400,738,009</td> <td>426,656,900     </td> <td>2013</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Harry Potter and the Deathly Hallows Part 2  </td> <td>Warner Bros.        </td> <td>381,011,219</td> <td>417,512,200     </td> <td>2011</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Finding Nemo                                 </td> <td>Buena Vista (Disney)</td> <td>380,843,261</td> <td>535,802,700     </td> <td>2003</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Star Wars: Episode III - Revenge of the Sith </td> <td>Fox                 </td> <td>380,270,577</td> <td>516,123,900     </td> <td>2005</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>The Lord of the Rings: The Return of the King</td> <td>New Line            </td> <td>377,845,905</td> <td>536,265,400     </td> <td>2003</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Spider-Man 2                                 </td> <td>Sony                </td> <td>373,585,825</td> <td>523,381,100     </td> <td>2004</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>The Passion of the Christ                    </td> <td>NM                  </td> <td>370,782,930</td> <td>519,432,100     </td> <td>2004</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Despicable Me 2                              </td> <td>Universal           </td> <td>368,061,265</td> <td>407,978,700     </td> <td>2013</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Inside Out                                   </td> <td>Buena Vista (Disney)</td> <td>356,461,711</td> <td>375,723,400     </td> <td>2015</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (170 rows omitted)</p

# %%
top.barh('Title', 'Gross')

# %%
top.group('Studio').barh('Studio', 'count')

# %%
top.group('Studio').sort('count', descending=True).barh('Studio', 'count')

# %%
top.select([0, 2, 3]).barh('Title')

# %% [markdown]
# ## Histograms

# %%
in_millions = np.round(top.column(3)/1000000, 2)
millions = top.select(['Title', 'Year']).with_column('Millions', in_millions)
millions
# Out:
# Title                                     | Year | Millions
# Star Wars: The Force Awakens              | 2015 | 906.72
# Avatar                                    | 2009 | 846.12
# Titanic                                   | 1997 | 1178.63
# Jurassic World                            | 2015 | 687.73
# Marvel's The Avengers                     | 2012 | 668.87
# The Dark Knight                           | 2008 | 647.76
# Star Wars: Episode I - The Phantom Menace | 1999 | 785.72
# Star Wars                                 | 1977 | 1549.64
# Avengers: Age of Ultron                   | 2015 | 465.68
# The Dark Knight Rises                     | 2012 | 500.96
# ... (190 rows omitted)

# %%
millions.hist('Millions')

# %%
millions.hist('Millions', bins=np.arange(300,2001,100))

# %%
millions.bin('Millions', bins=np.arange(300,2001,100))
# Out:
# bin  | Millions count
# 300  | 81
# 400  | 52
# 500  | 28
# 600  | 16
# 700  | 7
# 800  | 5
# 900  | 3
# 1000 | 1
# 1100 | 3
# 1200 | 2
# ... (8 rows omitted)

# %%
PercentFormatter().format_value(81/millions.num_rows/(400-300))
# Out:
# '0.41%'

# %%
millions.hist('Millions', bins=np.arange(300,2001,100), normed=False)

# %%
millions.bin('Millions', bins=[300, 400, 500, 600, 700, 2000])
# Out:
# bin  | Millions count
# 300  | 81
# 400  | 52
# 500  | 28
# 600  | 16
# 700  | 23
# 2000 | 0

# %%
millions.hist('Millions', bins=[300, 400, 500, 600, 700, 2000], normed=False)

# %%
millions.hist('Millions', bins=[300, 400, 500, 600, 700, 2000])

# %%
trips = Table.read_table('trip.csv')
trips
# Out:
# Trip ID | Duration | Start Date      | Start Station                                 | Start Terminal | End Date        | End Station                                   | End Terminal | Bike # | Subscriber Type | Zip Code
# 913460  | 765      | 8/31/2015 23:26 | Harry Bridges Plaza (Ferry Building)          | 50             | 8/31/2015 23:39 | San Francisco Caltrain (Townsend at 4th)      | 70           | 288    | Subscriber      | 2139
# 913459  | 1036     | 8/31/2015 23:11 | San Antonio Shopping Center                   | 31             | 8/31/2015 23:28 | Mountain View City Hall                       | 27           | 35     | Subscriber      | 95032
# 913455  | 307      | 8/31/2015 23:13 | Post at Kearny                                | 47             | 8/31/2015 23:18 | 2nd at South Park                             | 64           | 468    | Subscriber      | 94107
# 913454  | 409      | 8/31/2015 23:10 | San Jose City Hall                            | 10             | 8/31/2015 23:17 | San Salvador at 1st                           | 8            | 68     | Subscriber      | 95113
# 913453  | 789      | 8/31/2015 23:09 | Embarcadero at Folsom                         | 51             | 8/31/2015 23:22 | Embarcadero at Sansome                        | 60           | 487    | Customer        | 9069
# 913452  | 293      | 8/31/2015 23:07 | Yerba Buena Center of the Arts (3rd @ Howard) | 68             | 8/31/2015 23:12 | San Francisco Caltrain (Townsend at 4th)      | 70           | 538    | Subscriber      | 94118
# 913451  | 896      | 8/31/2015 23:07 | Embarcadero at Folsom                         | 51             | 8/31/2015 23:22 | Embarcadero at Sansome                        | 60           | 363    | Customer        | 92562
# 913450  | 255      | 8/31/2015 22:16 | Embarcadero at Sansome                        | 60             | 8/31/2015 22:20 | Steuart at Market                             | 74           | 470    | Subscriber      | 94111
# 913449  | 126      | 8/31/2015 22:12 | Beale at Market                               | 56             | 8/31/2015 22:15 | Temporary Transbay Terminal (Howard at Beale) | 55           | 439    | Subscriber      | 94130
# 913448  | 932      | 8/31/2015 21:57 | Post at Kearny                                | 47             | 8/31/2015 22:12 | South Van Ness at Market                      | 66           | 472    | Subscriber      | 94702
# ... (354142 rows omitted)

# %%
commute = trips.where(trips.column('Duration') < 1800)
commute.hist('Duration')

# %%
commute.hist('Duration', bins=np.arange(60, 1801, 10))
