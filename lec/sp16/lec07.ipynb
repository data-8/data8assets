# %%
import numpy as np
np.set_printoptions(threshold=50, linewidth=50)

# %%
# From Lecture 6
from datascience import *
full = Table.read_table('NC-EST2014-AGESEX-RES.csv')
partial = full.select(['SEX', 'AGE', 4, 8])
simple = partial.relabeled(2, '2010').relabeled(3, '2014')
census = simple.with_columns([
        'Change', simple.column('2014')-simple.column('2010'),
        'Growth', (simple.column('2014')/simple.column('2010')) ** (1/4) - 1
    ])
census.set_format('Growth', PercentFormatter)
census.set_format([2, 3, 4], NumberFormatter)
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 0    | 0    | 3,951,330   | 3,948,350   | -2,980    | -0.02%
# 0    | 1    | 3,957,888   | 3,962,123   | 4,235     | 0.03%
# 0    | 2    | 4,090,862   | 3,957,772   | -133,090  | -0.82%
# 0    | 3    | 4,111,920   | 4,005,190   | -106,730  | -0.66%
# 0    | 4    | 4,077,552   | 4,003,448   | -74,104   | -0.46%
# 0    | 5    | 4,064,653   | 4,004,858   | -59,795   | -0.37%
# 0    | 6    | 4,073,013   | 4,134,352   | 61,339    | 0.37%
# 0    | 7    | 4,043,047   | 4,154,000   | 110,953   | 0.68%
# 0    | 8    | 4,025,604   | 4,119,524   | 93,920    | 0.58%
# 0    | 9    | 4,125,415   | 4,106,832   | -18,583   | -0.11%
# ... (296 rows omitted)

# %%
males = census.where('SEX', 1)
females = census.where('SEX', 2)

# %%
females
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 2    | 0    | 1,932,910   | 1,930,493   | -2,417    | -0.03%
# 2    | 1    | 1,937,556   | 1,938,870   | 1,314     | 0.02%
# 2    | 2    | 2,002,177   | 1,935,270   | -66,907   | -0.85%
# 2    | 3    | 2,010,648   | 1,956,572   | -54,076   | -0.68%
# 2    | 4    | 1,993,240   | 1,959,950   | -33,290   | -0.42%
# 2    | 5    | 1,988,080   | 1,961,391   | -26,689   | -0.34%
# 2    | 6    | 1,993,603   | 2,024,024   | 30,421    | 0.38%
# 2    | 7    | 1,979,908   | 2,031,760   | 51,852    | 0.65%
# 2    | 8    | 1,971,142   | 2,014,402   | 43,260    | 0.54%
# 2    | 9    | 2,018,378   | 2,009,560   | -8,818    | -0.11%
# ... (92 rows omitted)

# %% [markdown]
# #### Discussion question

# %%
females.sort('2014', descending=True).column('AGE').item(1)
# Out:
# 54

# %%
males.sort('2014', descending=True)
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 1    | 999  | 152,089,484 | 156,936,487 | 4,847,003 | 0.79%
# 1    | 23   | 2,151,095   | 2,399,883   | 248,788   | 2.77%
# 1    | 24   | 2,161,380   | 2,391,398   | 230,018   | 2.56%
# 1    | 22   | 2,188,228   | 2,367,842   | 179,614   | 1.99%
# 1    | 21   | 2,241,095   | 2,310,734   | 69,639    | 0.77%
# 1    | 25   | 2,177,171   | 2,295,836   | 118,665   | 1.34%
# 1    | 20   | 2,331,846   | 2,269,570   | -62,276   | -0.67%
# 1    | 54   | 2,091,677   | 2,242,828   | 151,151   | 1.76%
# 1    | 26   | 2,102,375   | 2,240,026   | 137,651   | 1.60%
# 1    | 19   | 2,334,906   | 2,220,790   | -114,116  | -1.24%
# ... (92 rows omitted)

# %%
males.where(males.column('Change') > 300000).sort('AGE').show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th> <th>2010</th> <th>2014</th> <th>Change</th> <th>Growth</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1   </td> <td>64  </td> <td>1,291,843  </td> <td>1,661,474  </td> <td>369,631  </td> <td>6.49% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>65  </td> <td>1,272,693  </td> <td>1,607,688  </td> <td>334,995  </td> <td>6.02% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>66  </td> <td>1,239,805  </td> <td>1,589,127  </td> <td>349,322  </td> <td>6.40% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>67  </td> <td>1,270,148  </td> <td>1,653,257  </td> <td>383,109  </td> <td>6.81% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>999 </td> <td>152,089,484</td> <td>156,936,487</td> <td>4,847,003</td> <td>0.79% </td>
#         </tr>
#     </tbody>
# </table>

# %%
males.where(np.logical_and(males.column('AGE') > 55, 
                           males.column('AGE') < 70)).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th> <th>2010</th> <th>2014</th> <th>Change</th> <th>Growth</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>1   </td> <td>56  </td> <td>1,984,480  </td> <td>2,140,722  </td> <td>156,242  </td> <td>1.91% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>57  </td> <td>1,910,028  </td> <td>2,110,149  </td> <td>200,121  </td> <td>2.52% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>58  </td> <td>1,838,703  </td> <td>2,027,959  </td> <td>189,256  </td> <td>2.48% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>59  </td> <td>1,779,504  </td> <td>2,006,900  </td> <td>227,396  </td> <td>3.05% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>60  </td> <td>1,742,232  </td> <td>1,914,009  </td> <td>171,777  </td> <td>2.38% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>61  </td> <td>1,691,413  </td> <td>1,837,080  </td> <td>145,667  </td> <td>2.09% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>62  </td> <td>1,679,074  </td> <td>1,763,504  </td> <td>84,430   </td> <td>1.23% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>63  </td> <td>1,753,914  </td> <td>1,701,827  </td> <td>-52,087  </td> <td>-0.75%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>64  </td> <td>1,291,843  </td> <td>1,661,474  </td> <td>369,631  </td> <td>6.49% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>65  </td> <td>1,272,693  </td> <td>1,607,688  </td> <td>334,995  </td> <td>6.02% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>66  </td> <td>1,239,805  </td> <td>1,589,127  </td> <td>349,322  </td> <td>6.40% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>67  </td> <td>1,270,148  </td> <td>1,653,257  </td> <td>383,109  </td> <td>6.81% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>68  </td> <td>1,105,702  </td> <td>1,211,480  </td> <td>105,778  </td> <td>2.31% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>69  </td> <td>1,006,786  </td> <td>1,187,554  </td> <td>180,768  </td> <td>4.21% </td>
#         </tr>
#     </tbody>
# </table>

# %%
census.where(np.logical_or(census.column('AGE') == 18,
                           census.column('AGE') == 19))
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 0    | 18   | 4,491,005   | 4,225,590   | -265,415  | -1.51%
# 0    | 19   | 4,571,385   | 4,326,394   | -244,991  | -1.37%
# 1    | 18   | 2,305,733   | 2,165,062   | -140,671  | -1.56%
# 1    | 19   | 2,334,906   | 2,220,790   | -114,116  | -1.24%
# 2    | 18   | 2,185,272   | 2,060,528   | -124,744  | -1.46%
# 2    | 19   | 2,236,479   | 2,105,604   | -130,875  | -1.50%

# %% [markdown]
# ## Functions

# %%
def percent(x):
    return round(100*x, 2)

# %%
percent(1/6)
# Out:
# 16.67

# %%
sixth = 1/6
percent(sixth)
# Out:
# 16.67

# %%
percent(1/6000)
# Out:
# 0.02

# %%
percent(1/60000)
# Out:
# 0.0

# %%
def percent(x):
    if x < 0.00005:
        return 100 * x
    return round(100 * x, 2)

# %%
print('1/6 =', percent(1/6))
print('1/6000 =', percent(1/6000))
print('1/60000 =', percent(1/60000))
# Out:
# 1/6 = 16.67
# 1/6000 = 0.02
# 1/60000 = 0.0016666666666666668

# %%
print('1/60000000000 =', percent(1/60000000000))
# Out:
# 1/60000000000 = 1.6666666666666667e-09

# %%
def percent(x):
    if x < 1e-8:
        return 0.0
    elif x < 0.00005:
        return 100 * x
    else:
        return round(100 * x, 2)

# %%
print('1/6 =', percent(1/6))
print('1/6000 =', percent(1/6000))
print('1/60000 =', percent(1/60000))
print('1/60000000000 =', percent(1/60000000000))
# Out:
# 1/6 = 16.67
# 1/6000 = 0.02
# 1/60000 = 0.0016666666666666668
# 1/60000000000 = 0.0

# %%
percent(-1/6)
# Out:
# 0.0

# %%
-1/6 < 1e-8
# Out:
# True

# %%
def percent(x):
    if abs(x) < 1e-8:
        return 0.0
    elif abs(x) < 0.00005:
        return 100 * x
    else:
        return round(100 * x, 2)

# %%
print('1/6 =', percent(1/6))
print('1/6000 =', percent(1/6000))
print('1/60000 =', percent(1/60000))
print('1/60000000000 =', percent(1/60000000000))
print('-1/6 =', percent(-1/6))
# Out:
# 1/6 = 16.67
# 1/6000 = 0.02
# 1/60000 = 0.0016666666666666668
# 1/60000000000 = 0.0
# -1/6 = -16.67

# %%
census.where(np.logical_or(census.column('AGE') == 18,
                           census.column('AGE') == 19))
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 0    | 18   | 4,491,005   | 4,225,590   | -265,415  | -1.51%
# 0    | 19   | 4,571,385   | 4,326,394   | -244,991  | -1.37%
# 1    | 18   | 2,305,733   | 2,165,062   | -140,671  | -1.56%
# 1    | 19   | 2,334,906   | 2,220,790   | -114,116  | -1.24%
# 2    | 18   | 2,185,272   | 2,060,528   | -124,744  | -1.46%
# 2    | 19   | 2,236,479   | 2,105,604   | -130,875  | -1.50%

# %%
def voting_teens(t):
    return t.where(np.logical_or(t.column('AGE') == 18, t.column('AGE') == 19))

# %%
voting_teens(females)
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 2    | 18   | 2,185,272   | 2,060,528   | -124,744  | -1.46%
# 2    | 19   | 2,236,479   | 2,105,604   | -130,875  | -1.50%

# %%
voting_teens(males)
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 1    | 18   | 2,305,733   | 2,165,062   | -140,671  | -1.56%
# 1    | 19   | 2,334,906   | 2,220,790   | -114,116  | -1.24%

# %%
voting_teens(census)
# Out:
# SEX  | AGE  | 2010        | 2014        | Change    | Growth
# 0    | 18   | 4,491,005   | 4,225,590   | -265,415  | -1.51%
# 0    | 19   | 4,571,385   | 4,326,394   | -244,991  | -1.37%
# 1    | 18   | 2,305,733   | 2,165,062   | -140,671  | -1.56%
# 1    | 19   | 2,334,906   | 2,220,790   | -114,116  | -1.24%
# 2    | 18   | 2,185,272   | 2,060,528   | -124,744  | -1.46%
# 2    | 19   | 2,236,479   | 2,105,604   | -130,875  | -1.50%

# %%
voting_teens(census).column('Growth')
# Out:
# array([-0.01511402, -0.01367608, -0.01561422,
#        -0.01244902, -0.01458707, -0.01496204])

# %% [markdown]
# #### Discussion Question

# %%
def f(s):
    return np.round(s / sum(s) * 100, 2)

# %%
f(np.array([1, 1, 3, 1, 2]))
# Out:
# array([ 12.5,  12.5,  37.5,  12.5,  25. ])

# %%
f(females.where(females.column('AGE') < 5).column('2014'))
# Out:
# array([ 19.86,  19.94,  19.91,  20.13,  20.16])

# %%
voting_teens(census).apply(percent, 'Growth')
# Out:
# array([-1.51, -1.37, -1.56, -1.24, -1.46, -1.5 ])

# %%
def mf(code):
    if code == 0:
        return 'Total'
    elif code == 1:
        return 'Male'
    elif code == 2:
        return 'Female'
census_mf = census.with_column('SEX', census.apply(mf, 'SEX'))
census_mf.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>SEX</th> <th>AGE</th> <th>2010</th> <th>2014</th> <th>Change</th> <th>Growth</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Total </td> <td>0   </td> <td>3,951,330  </td> <td>3,948,350  </td> <td>-2,980   </td> <td>-0.02%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>1   </td> <td>3,957,888  </td> <td>3,962,123  </td> <td>4,235    </td> <td>0.03% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>2   </td> <td>4,090,862  </td> <td>3,957,772  </td> <td>-133,090 </td> <td>-0.82%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>3   </td> <td>4,111,920  </td> <td>4,005,190  </td> <td>-106,730 </td> <td>-0.66%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>4   </td> <td>4,077,552  </td> <td>4,003,448  </td> <td>-74,104  </td> <td>-0.46%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>5   </td> <td>4,064,653  </td> <td>4,004,858  </td> <td>-59,795  </td> <td>-0.37%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>6   </td> <td>4,073,013  </td> <td>4,134,352  </td> <td>61,339   </td> <td>0.37% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>7   </td> <td>4,043,047  </td> <td>4,154,000  </td> <td>110,953  </td> <td>0.68% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>8   </td> <td>4,025,604  </td> <td>4,119,524  </td> <td>93,920   </td> <td>0.58% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>9   </td> <td>4,125,415  </td> <td>4,106,832  </td> <td>-18,583  </td> <td>-0.11%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>10  </td> <td>4,187,063  </td> <td>4,115,254  </td> <td>-71,809  </td> <td>-0.43%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>11  </td> <td>4,115,511  </td> <td>4,085,636  </td> <td>-29,875  </td> <td>-0.18%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>12  </td> <td>4,113,280  </td> <td>4,068,790  </td> <td>-44,490  </td> <td>-0.27%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>13  </td> <td>4,119,666  </td> <td>4,169,346  </td> <td>49,680   </td> <td>0.30% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>14  </td> <td>4,145,614  </td> <td>4,232,480  </td> <td>86,866   </td> <td>0.52% </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>15  </td> <td>4,231,003  </td> <td>4,163,723  </td> <td>-67,280  </td> <td>-0.40%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>16  </td> <td>4,313,252  </td> <td>4,167,234  </td> <td>-146,018 </td> <td>-0.86%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td>17  </td> <td>4,376,368  </td> <td>4,184,706  </td> <td>-191,662 </td> <td>-1.11%</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>Total </td> <td
  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>28  </td> <td>2144666          </td> <td>2207185        </td> <td>4351851         </td> <td>50.72%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29  </td> <td>2169563          </td> <td>2217913        </td> <td>4387476         </td> <td>50.55%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>30  </td> <td>2110672          </td> <td>2140108        </td> <td>4250780         </td> <td>50.35%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>31  </td> <td>2148981          </td> <td>2169725        </td> <td>4318706         </td> <td>50.24%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>32  </td> <td>2154232          </td> <td>2165840        </td> <td>4320072         </td> <td>50.13%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>33  </td> <td>2135416          </td> <td>2140697        </td> <td>4276113         </td> <td>50.06%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>34  </td> <td>2170440          </td> <td>2192455        </td> <td>4362895         </td> <td>50.25%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>35  </td> <td>2046713          </td> <td>2047326        </td> <td>4094039         </td> <td>50.01%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>36  </td> <td>2009423          </td> <td>2004990        </td> <td>4014413         </td> <td>49.94%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>37  </td> <td>1995155          </td> <td>1979035        </td> <td>3974190         </td> <td>49.80%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>38  </td> <td>1936610          </td> <td>1922571        </td> <td>3859181         </td> <td>49.82%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>39  </td> <td>1993913          </td> <td>1985914        </td> <td>3979827         </td> <td>49.90%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>40  </td> <td>1940627          </td> <td>1916261        </td> <td>3856888         </td> <td>49.68%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>41  </td> <td>1977497          </td> <td>1939916        </td> <td>3917413         </td> <td>49.52%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>42  </td> <td>2064604          </td> <td>2031325        </td> <td>4095929         </td> <td>49.59%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>43  </td> <td>2184835          </td> <td>2147656        </td> <td>4332491         </td> <td>49.57%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>44  </td> <td>2204527          </td> <td>2184235        </td> <td>4388762         </td> <td>49.77%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>45  </td> <td>2094227          </td> <td>2067223        </td> <td>4161450         </td> <td>49.68%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>46  </td> <td>2053539          </td> <td>2022698        </td> <td>4076237         </td> <td>49.62%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>47  </td> <td>2062844          </td> <td>2019306        </td> <td>4082150         </td> <td>49.47%  </td>
#         </tr>
#     </tbody>

# %%
decade = census_mf.with_column('Nearest Decade', np.round(census.column('AGE'), -1))
decade
# Out:
# SEX   | AGE  | 2010        | 2014        | Change    | Growth | Nearest Decade
# Total | 0    | 3,951,330   | 3,948,350   | -2,980    | -0.02% | 0
# Total | 1    | 3,957,888   | 3,962,123   | 4,235     | 0.03%  | 0
# Total | 2    | 4,090,862   | 3,957,772   | -133,090  | -0.82% | 0
# Total | 3    | 4,111,920   | 4,005,190   | -106,730  | -0.66% | 0
# Total | 4    | 4,077,552   | 4,003,448   | -74,104   | -0.46% | 0
# Total | 5    | 4,064,653   | 4,004,858   | -59,795   | -0.37% | 0
# Total | 6    | 4,073,013   | 4,134,352   | 61,339    | 0.37%  | 10
# Total | 7    | 4,043,047   | 4,154,000   | 110,953   | 0.68%  | 10
# Total | 8    | 4,025,604   | 4,119,524   | 93,920    | 0.58%  | 10
# Total | 9    | 4,125,415   | 4,106,832   | -18,583   | -0.11% | 10
# ... (296 rows omitted)

# %%
pivoted = decade.relabeled('2014', 'Population').pivot('SEX', 'Nearest Decade', 'Population', sum)
fraction = pivoted.with_column('Fraction', pivoted.column(2)/pivoted.column(3))
fraction.set_format('Fraction', PercentFormatter).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Nearest Decade</th> <th>Female Population</th> <th>Male Population</th> <th>Total Population</th> <th>Fraction</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0             </td> <td>11682546         </td> <td>12199195       </td> <td>23881741        </td> <td>51.08%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>10            </td> <td>18200033         </td> <td>18986181       </td> <td>37186214        </td> <td>51.06%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>20            </td> <td>23670129         </td> <td>24819286       </td> <td>48489415        </td> <td>51.18%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>30            </td> <td>19332532         </td> <td>19674378       </td> <td>39006910        </td> <td>50.44%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>40            </td> <td>22448131         </td> <td>22226452       </td> <td>44674583        </td> <td>49.75%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>50            </td> <td>19939580         </td> <td>19357821       </td> <td>39297401        </td> <td>49.26%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>60            </td> <td>22532460         </td> <td>20929570       </td> <td>43462030        </td> <td>48.16%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>70            </td> <td>12272484         </td> <td>10741357       </td> <td>23013841        </td> <td>46.67%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>80            </td> <td>8355017          </td> <td>6252642        </td> <td>14607659        </td> <td>42.80%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>90            </td> <td>3082361          </td> <td>1618652        </td> <td>4701013         </td> <td>34.43%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>100           </td> <td>405296           </td> <td>130953         </td> <td>536249          </td> <td>24.42%  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1000          </td> <td>161920569        </td> <td>156936487      </td> <td>318857056       </td> <td>49.22%  </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Group

# %%
cardio = Table.read_table("~/Downloads/Data 8 Cardio Participation Log (Responses) - Form Responses 1.csv")
cardio
# Out:
# Timestamp          | On what day did you attend? | How many laps did you complete? | In how many minutes? | How tired were you at the end? | What's your identifier?
# 1/20/2016 22:05:05 | Thursday, 1/21              | 5                               | 14                   | 4                              | blue running shoes with black black pants.
# 1/21/2016 8:07:05  | Thursday, 1/21              | 22                              | 30                   | 3                              | Cal lights>WIRAs
# 1/21/2016 8:23:16  | Thursday, 1/21              | 6                               | 18                   | 6                              | Ontario
# 1/21/2016 8:36:59  | Thursday, 1/21              | 8                               | 20                   | 5                              | Smooth Criminal
# 1/21/2016 8:37:28  | Thursday, 1/21              | 8                               | 20                   | 5                              | Tomato
# 1/21/2016 9:02:25  | Thursday, 1/21              | 5.5                             | 25                   | 5                              | SS
# 1/21/2016 9:07:08  | Thursday, 1/21              | 12                              | 35                   | 4                              | astennet
# 1/21/2016 9:21:12  | Thursday, 1/21              | 8                               | 35                   | 3                              | BR
# 1/21/2016 9:29:18  | Thursday, 1/21              | 6                               | 30                   | 5                              | TrueLoveInAGraph
# 1/21/2016 9:38:18  | Thursday, 1/21              | 5                               | 11                   | 3                              | Edward Snowden
# ... (16 rows omitted)

# %%
days = cardio.select([1, 2, 3]).group(0, sum)
days
# Out:
# On what day did you attend? | How many laps did you complete? sum | In how many minutes? sum
# Thursday, 1/21              | 131                                 | 394
# Thursday, 1/28              | 99                                  | 265.5

# %%
days.with_column('Minutes/Lap', days.column(2)/days.column(1))
# Out:
# On what day did you attend? | How many laps did you complete? sum | In how many minutes? sum | Minutes/Lap
# Thursday, 1/21              | 131                                 | 394                      | 3.00763
# Thursday, 1/28              | 99                                  | 265.5                    | 2.68182
