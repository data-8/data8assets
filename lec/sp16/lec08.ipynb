# %%
# From Lecture 6
import numpy as np
from datascience import *
full = Table.read_table('NC-EST2014-AGESEX-RES.csv')
partial = full.select(['SEX', 'AGE', 8])
census = partial.relabeled(2, 'Population')
census.set_format([2], NumberFormatter)
# Out:
# SEX  | AGE  | Population
# 0    | 0    | 3,948,350
# 0    | 1    | 3,962,123
# 0    | 2    | 3,957,772
# 0    | 3    | 4,005,190
# 0    | 4    | 4,003,448
# 0    | 5    | 4,004,858
# 0    | 6    | 4,134,352
# 0    | 7    | 4,154,000
# 0    | 8    | 4,119,524
# 0    | 9    | 4,106,832
# ... (296 rows omitted)

# %%
males = census.where('SEX', 1)
females = census.where('SEX', 2)

# %%
females.sort('Population', descending=True)
# Out:
# SEX  | AGE  | Population
# 2    | 999  | 161,920,569
# 2    | 54   | 2,331,961
# 2    | 53   | 2,316,131
# 2    | 24   | 2,301,237
# 2    | 23   | 2,298,701
# 2    | 51   | 2,283,261
# 2    | 52   | 2,282,051
# 2    | 50   | 2,279,824
# 2    | 55   | 2,263,367
# 2    | 56   | 2,254,749
# ... (92 rows omitted)

# %%
males.sort('Population', descending=True)
# Out:
# SEX  | AGE  | Population
# 1    | 999  | 156,936,487
# 1    | 23   | 2,399,883
# 1    | 24   | 2,391,398
# 1    | 22   | 2,367,842
# 1    | 21   | 2,310,734
# 1    | 25   | 2,295,836
# 1    | 20   | 2,269,570
# 1    | 54   | 2,242,828
# 1    | 26   | 2,240,026
# 1    | 19   | 2,220,790
# ... (92 rows omitted)

# %% [markdown]
# ## Apply

# %%
def mf(code):
    if code == 0:
        return 'Total'
    elif code == 1:
        return 'Male'
    elif code == 2:
        return 'Female'
    
mf(2)
# Out:
# 'Female'

# %%
census_mf = census.with_column('MF', census.apply(mf, 'SEX'))
census_mf
# Out:
# SEX  | AGE  | Population  | MF
# 0    | 0    | 3,948,350   | Total
# 0    | 1    | 3,962,123   | Total
# 0    | 2    | 3,957,772   | Total
# 0    | 3    | 4,005,190   | Total
# 0    | 4    | 4,003,448   | Total
# 0    | 5    | 4,004,858   | Total
# 0    | 6    | 4,134,352   | Total
# 0    | 7    | 4,154,000   | Total
# 0    | 8    | 4,119,524   | Total
# 0    | 9    | 4,106,832   | Total
# ... (296 rows omitted)

# %%
pivoted = census_mf.pivot('MF', 'AGE', 'Population', sum)
fraction = pivoted.with_column('Male Percentage', pivoted.column(2)/pivoted.column(3))
fraction.set_format([1, 2, 3], NumberFormatter)
fraction.set_format(4, PercentFormatter).show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>AGE</th> <th>Female Population</th> <th>Male Population</th> <th>Total Population</th> <th>Male Percentage</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>0   </td> <td>1,930,493        </td> <td>2,017,857      </td> <td>3,948,350       </td> <td>51.11%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>1   </td> <td>1,938,870        </td> <td>2,023,253      </td> <td>3,962,123       </td> <td>51.06%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>2   </td> <td>1,935,270        </td> <td>2,022,502      </td> <td>3,957,772       </td> <td>51.10%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>3   </td> <td>1,956,572        </td> <td>2,048,618      </td> <td>4,005,190       </td> <td>51.15%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>4   </td> <td>1,959,950        </td> <td>2,043,498      </td> <td>4,003,448       </td> <td>51.04%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>5   </td> <td>1,961,391        </td> <td>2,043,467      </td> <td>4,004,858       </td> <td>51.02%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>6   </td> <td>2,024,024        </td> <td>2,110,328      </td> <td>4,134,352       </td> <td>51.04%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>7   </td> <td>2,031,760        </td> <td>2,122,240      </td> <td>4,154,000       </td> <td>51.09%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>8   </td> <td>2,014,402        </td> <td>2,105,122      </td> <td>4,119,524       </td> <td>51.10%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>9   </td> <td>2,009,560        </td> <td>2,097,272      </td> <td>4,106,832       </td> <td>51.07%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>10  </td> <td>2,015,380        </td> <td>2,099,874      </td> <td>4,115,254       </td> <td>51.03%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>11  </td> <td>2,001,949        </td> <td>2,083,687      </td> <td>4,085,636       </td> <td>51.00%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>12  </td> <td>1,993,547        </td> <td>2,075,243      </td> <td>4,068,790       </td> <td>51.00%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>13  </td> <td>2,041,159        </td> <td>2,128,187      </td> <td>4,169,346       </td> <td>51.04%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>14  </td> <td>2,068,252        </td> <td>2,164,228      </td> <td>4,232,480       </td> <td>51.13%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>15  </td> <td>2,035,299        </td> <td>2,128,424      </td> <td>4,163,723       </td> <td>51.12%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>16  </td> <td>2,036,296        </td> <td>2,130,938      </td> <td>4,167,234       </td> <td>51.14%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>17  </td> <td>2,045,897        </td> <td>2,138,809      </td> <td>4,184,706       </td> <td>51.11%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>18  </td> <td>2,060,528        </td> <td>2,165,062      </td> <td>4,225,590       </td> <td>51.24%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>19  </td> <td>2,105,604        </td> <td>2,220,790      </td> <td>4,326,394       </td> <td>51.33%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>20  </td> <td>2,149,317        </td> <td>2,269,570      </td> <td>4,418,887       </td> <td>51.36%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>21  </td> <td>2,179,012        </td> <td>2,310,734      </td> <td>4,489,746       </td> <td>51.47%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>22  </td> <td>2,244,480        </td> <td>2,367,842      </td> <td>4,612,322       </td> <td>51.34%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>23  </td> <td>2,298,701        </td> <td>2,399,883      </td> <td>4,698,584       </td> <td>51.08%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>24  </td> <td>2,301,237        </td> <td>2,391,398      </td> <td>4,692,635       </td> <td>50.96%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>25  </td> <td>2,213,758        </td> <td>2,295,836      </td> <td>4,509,594       </td> <td>50.91%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>26  </td> <td>2,166,446        </td> <td>2,240,026      </td> <td>4,406,472       </td> <td>50.83%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>27  </td> <td>2,132,116        </td> <td>2,200,429      </td> <td>4,332,545       </td> <td>50.79%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>28  </td> <td>2,144,666        </td> <td>2,207,185      </td> <td>4,351,851       </td> <td>50.72%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>29  </td> <td>2,169,563        </td> <td>2,217,913      </td> <td>4,387,476       </td> <td>50.55%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>30  </td> <td>2,110,672        </td> <td>2,140,108      </td> <td>4,250,780       </td> <td>50.35%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>31  </td> <td>2,148,981        </td> <td>2,169,725      </td> <td>4,318,706       </td> <td>50.24%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>32  </td> <td>2,154,232        </td> <td>2,165,840      </td> <td>4,320,072       </td> <td>50.13%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>33  </td> <td>2,135,416        </td> <td>2,140,697      </td> <td>4,276,113       </td> <td>50.06%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>34  </td> <td>2,170,440        </td> <td>2,192,455      </td> <td>4,362,895       </td> <td>50.25%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>35  </td> <td>2,046,713        </td> <td>2,047,326      </td> <td>4,094,039       </td> <td>50.01%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>36  </td> <td>2,009,423        </td> <td>2,004,990      </td> <td>4,014,413       </td> <td>49.94%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>37  </td> <td>1,995,155        </td> <td>1,979,035      </td> <td>3,974,190       </td> <td>49.80%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>38  </td> <td>1,936,610        </td> <td>1,922,571      </td> <td>3,859,181       </td> <td>49.82%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>39  </td> <td>1,993,913        </td> <td>1,985,914      </td> <td>3,979,827       </td> <td>49.90%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>40  </td> <td>1,940,627        </td> <td>1,916,261      </td> <td>3,856,888       </td> <td>49.68%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>41  </td> <td>1,977,497        </td> <td>1,939,916      </td> <td>3,917,413       </td> <td>49.52%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>42  </td> <td>2,064,604        </td> <td>2,031,325      </td> <td>4,095,929       </td> <td>49.59%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>43  </td> <td>2,184,835        </td> <td>2,147,656      </td> <td>4,332,491       </td> <td>49.57%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>44  </td> <td>2,204,527        </td> <td>2,184,235      </td> <td>4,388,762       </td> <td>49.77%         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>45  </td> <td>2,094,227        </td> <td>2,067,223      </td> <td>4,161,450       </td> <td>49.68%         </td>
#         </tr>
#     </tbod

# %% [markdown]
# ## Bikes

# %%
# Download data (it may take minutes)
import os
if not os.path.exists('201508_station_data.csv'):
    # !wget https://s3.amazonaws.com/babs-open-data/babs_open_data_year_2.zip && \
        unzip babs_open_data_year_2.zip && \
        rm 201508_status_data.csv babs_open_data_year_2.zip

# %%
trips = Table.read_table('201508_trip_data.csv')
trips
# Out:
# Trip ID | Duration | Start Date      | Start Station                                 | Start Terminal | End Date        | End Station                                   | End Terminal | Bike # | Subscriber Type | Zip Code
# 913460  | 765      | 8/31/2015 23:26 | Harry Bridges Plaza (Ferry Building)          | 50             | 8/31/2015 23:39 | San Francisco Caltrain (Townsend at 4th)      | 70           | 288    | Subscriber      | 2139
# 913459  | 1036     | 8/31/2015 23:11 | San Antonio Shopping Center                   | 31             | 8/31/2015 23:28 | Mountain View City Hall                       | 27           | 35     | Subscriber      | 95032
# 913455  | 307      | 8/31/2015 23:13 | Post at Kearny                                | 47             | 8/31/2015 23:18 | 2nd at South Park                             | 64           | 468    | Subscriber      | 94107
# 913454  | 409      | 8/31/2015 23:10 | San Jose City Hall                            | 10             | 8/31/2015 23:17 | San Salvador at 1st                           | 8            | 68     | Subscriber      | 95113
# 913453  | 789      | 8/31/2015 23:09 | Embarcadero at Folsom                         | 51             | 8/31/2015 23:22 | Embarcadero at Sansome                        | 60           | 487    | Customer        | 9069
# 913452  | 293      | 8/31/2015 23:07 | Yerba Buena Center of the Arts (3rd @ Howard) | 68             | 8/31/2015 23:12 | San Francisco Caltrain (Townsend at 4th)      | 70           | 538    | Subscriber      | 94118
# 913451  | 896      | 8/31/2015 23:07 | Embarcadero at Folsom                         | 51             | 8/31/2015 23:22 | Embarcadero at Sansome                        | 60           | 363    | Customer        | 92562
# 913450  | 255      | 8/31/2015 22:16 | Embarcadero at Sansome                        | 60             | 8/31/2015 22:20 | Steuart at Market                             | 74           | 470    | Subscriber      | 94111
# 913449  | 126      | 8/31/2015 22:12 | Beale at Market                               | 56             | 8/31/2015 22:15 | Temporary Transbay Terminal (Howard at Beale) | 55           | 439    | Subscriber      | 94130
# 913448  | 932      | 8/31/2015 21:57 | Post at Kearny                                | 47             | 8/31/2015 22:12 | South Van Ness at Market                      | 66           | 472    | Subscriber      | 94702
# ... (354142 rows omitted)

# %%
starts = trips.select(3)
starts
# Out:
# Start Station
# Harry Bridges Plaza (Ferry Building)
# San Antonio Shopping Center
# Post at Kearny
# San Jose City Hall
# Embarcadero at Folsom
# Yerba Buena Center of the Arts (3rd @ Howard)
# Embarcadero at Folsom
# Embarcadero at Sansome
# Beale at Market
# Post at Kearny
# ... (354142 rows omitted)

# %% [markdown]
# ## Group

# %%
starts.group(0)
# Out:
# Start Station                    | count
# 2nd at Folsom                    | 7999
# 2nd at South Park                | 9469
# 2nd at Townsend                  | 14026
# 5th at Howard                    | 7708
# Adobe on Almaden                 | 562
# Arena Green / SAP Center         | 647
# Beale at Market                  | 8359
# Broadway St at Battery St        | 7676
# California Ave Caltrain Station  | 400
# Castro Street and El Camino Real | 1230
# ... (60 rows omitted)

# %%
starts.group(0).sort(1, descending=True)
# Out:
# Start Station                                 | count
# San Francisco Caltrain (Townsend at 4th)      | 26304
# San Francisco Caltrain 2 (330 Townsend)       | 21758
# Harry Bridges Plaza (Ferry Building)          | 17255
# Temporary Transbay Terminal (Howard at Beale) | 14436
# Embarcadero at Sansome                        | 14158
# 2nd at Townsend                               | 14026
# Townsend at 7th                               | 13752
# Steuart at Market                             | 13687
# Market at 10th                                | 11885
# Market at Sansome                             | 11431
# ... (60 rows omitted)

# %%
trips.select([3, 8])
# Out:
# Start Station                                 | Bike #
# Harry Bridges Plaza (Ferry Building)          | 288
# San Antonio Shopping Center                   | 35
# Post at Kearny                                | 468
# San Jose City Hall                            | 68
# Embarcadero at Folsom                         | 487
# Yerba Buena Center of the Arts (3rd @ Howard) | 538
# Embarcadero at Folsom                         | 363
# Embarcadero at Sansome                        | 470
# Beale at Market                               | 439
# Post at Kearny                                | 472
# ... (354142 rows omitted)

# %%
bikes = trips.select([3, 8]).group('Bike #', list)
bikes
# Out:
# Bike # | Start Station list
# 9      | ['San Jose Diridon Caltrain Station', 'MLK Library', 'SJ ...
# 10     | ['San Antonio Shopping Center', 'San Antonio Caltrain St ...
# 11     | ['St James Park', 'St James Park', 'Paseo de San Antonio ...
# 12     | ['Mountain View City Hall', 'Mountain View City Hall', ' ...
# 13     | ['Mountain View Caltrain Station', 'Castro Street and El ...
# 14     | ['San Jose Diridon Caltrain Station', 'Santa Clara at Al ...
# 15     | ['Redwood City Public Library', 'Redwood City Public Lib ...
# 16     | ['Temporary Transbay Terminal (Howard at Beale)', 'Golde ...
# 17     | ['San Jose Diridon Caltrain Station', 'St James Park', ' ...
# 18     | ['San Jose Civic Center', 'MLK Library', 'San Jose Dirid ...
# ... (658 rows omitted)

# %%
bikes.row(3).item(1)
# Out:
# ['Mountain View City Hall',
#  'Mountain View City Hall',
#  'Mountain View Caltrain Station',
#  'Castro Street and El Camino Real',
#  'Mountain View Caltrain Station',
#  'Evelyn Park and Ride',
#  'Mountain View Caltrain Station',
#  'Rengstorff Avenue / California Street',
#  'University and Emerson',
#  'University and Emerson',
#  'University and Emerson',
#  'University and Emerson',
#  'University and Emerson',
#  'Cowper at University',
#  'Palo Alto Caltrain Station',
#  'California Ave Caltrain Station',
#  'University and Emerson',
#  'University and Emerson',
#  'California Ave Caltrain Station',
#  'Palo Alto Caltrain Station',
#  'Park at Olive',
#  'Palo Alto Caltrain Station',
#  'San Antonio Shopping Center',
#  'San Antonio Caltrain Station',
#  'San Antonio Shopping Center',
#  'Palo Alto Caltrain Station',
#  'Cowper at University',
#  'Palo Alto Caltrain Station',
#  'Cowper at University',
#  'Palo Alto Caltrain Station',
#  'Cowper at University',
#  'Cowper at University',
#  'Palo Alto Caltrain Station',
#  'Palo Alto Caltrain Station',
#  'Cowper at University',
#  'Cowper at University',
#  'Palo Alto Caltrain Station',
#  'Palo Alto Caltrain Station',
#  'Park at Olive',
#  'California Ave Caltrain Station',
#  'University and Emerson',
#  'California Ave Caltrain Station',
#  'Palo Alto Caltrain Station',
#  'California Ave Caltrain Station',
#  'Park at Olive',
#  'Palo Alto Caltrain Station',
#  'Park at Olive',
#  'Palo Alto Caltrain Station',
#  'Palo Alto Caltrain Station',
#  'California Ave Caltrain Station',
#  'Palo Alto Caltrain Station',
#  'Cowper at University',
#  'University and Emerson',
#  'Palo Alto Caltrain Station',
#  'Cowper at University',
#  'Palo Alto Caltrain Station',
#  'Redwood City Caltrain Station',
#  'Redwood City Medical Center',
#  'MLK Library',
#  'Adobe on Almaden',
#  'San Jose Civic Center',
#  'San Jose Civic Center',
#  'Ryland Park',
#  'Paseo de San Antonio',
#  'Santa Clara at Almaden',
#  'San Jose Civic Center',
#  'Ryland Park',
#  'Japantown',
#  'San Jose Diridon Caltrain Station',
#  'MLK Library',
#  'SJSU - San Salvador at 9th',
#  'San Jose Diridon Caltrain Station',
#  'Santa Clara at Almaden',
#  'San Jose Diridon Caltrain Station',
#  'San Salvador at 1st',
#  'San Jose City Hall',
#  'San Jose Diridon Caltrain Station',
#  'SJSU - San Salvador at 9th',
#  'San Jose Diridon Caltrain Station',
#  'Ryland Park']

# %% [markdown]
# ## Groups

# %%
duration = trips.select([3, 6, 1])
duration
# Out:
# Start Station                                 | End Station                                   | Duration
# Harry Bridges Plaza (Ferry Building)          | San Francisco Caltrain (Townsend at 4th)      | 765
# San Antonio Shopping Center                   | Mountain View City Hall                       | 1036
# Post at Kearny                                | 2nd at South Park                             | 307
# San Jose City Hall                            | San Salvador at 1st                           | 409
# Embarcadero at Folsom                         | Embarcadero at Sansome                        | 789
# Yerba Buena Center of the Arts (3rd @ Howard) | San Francisco Caltrain (Townsend at 4th)      | 293
# Embarcadero at Folsom                         | Embarcadero at Sansome                        | 896
# Embarcadero at Sansome                        | Steuart at Market                             | 255
# Beale at Market                               | Temporary Transbay Terminal (Howard at Beale) | 126
# Post at Kearny                                | South Van Ness at Market                      | 932
# ... (354142 rows omitted)

# %%
shortest = duration.groups([0, 1], min)
shortest
# Out:
# Start Station | End Station                       | Duration min
# 2nd at Folsom | 2nd at Folsom                     | 61
# 2nd at Folsom | 2nd at South Park                 | 61
# 2nd at Folsom | 2nd at Townsend                   | 137
# 2nd at Folsom | 5th at Howard                     | 215
# 2nd at Folsom | Beale at Market                   | 219
# 2nd at Folsom | Broadway St at Battery St         | 351
# 2nd at Folsom | Civic Center BART (7th at Market) | 456
# 2nd at Folsom | Clay at Battery                   | 272
# 2nd at Folsom | Commercial at Montgomery          | 275
# 2nd at Folsom | Davis at Jackson                  | 396
# ... (1682 rows omitted)

# %%
shortest.where(0, 'Civic Center BART (7th at Market)').sort(2)
# Out:
# Start Station                     | End Station                       | Duration min
# Civic Center BART (7th at Market) | Civic Center BART (7th at Market) | 60
# Civic Center BART (7th at Market) | Powell Street BART                | 97
# Civic Center BART (7th at Market) | Market at 10th                    | 104
# Civic Center BART (7th at Market) | Golden Gate at Polk               | 141
# Civic Center BART (7th at Market) | San Francisco City Hall           | 151
# Civic Center BART (7th at Market) | Market at 4th                     | 164
# Civic Center BART (7th at Market) | 5th at Howard                     | 179
# Civic Center BART (7th at Market) | South Van Ness at Market          | 199
# Civic Center BART (7th at Market) | Market at Sansome                 | 254
# Civic Center BART (7th at Market) | Powell at Post (Union Square)     | 254
# ... (25 rows omitted)

# %%
stations = Table.read_table('201508_station_data.csv')
sf = stations.where('landmark', 'San Francisco')
Marker.map_table(sf.select(['lat', 'long', 'name']))
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;https://rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;https://birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_69cb4a60b57d43b4aedfb7989f612562&quot; style=&quot;width: 960px; height: 500px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 17,
#           minZoom: 10,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_69cb4a60b57d43b4aedfb7989f612562', {
#                                        center:[37.787914, -122.4034835],
#                                        zoom: 15,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#       var marker_1_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_1 = L.marker([37.795001,
# 							-122.39997],
# 							{'icon':marker_1_icon}
# 							);
#       marker_1.bindPopup(&quot;Clay at Battery&quot;);
#       marker_1._popup.options.maxWidth = 300;
#       map.addLayer(marker_1)
#
#       var marker_2_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_2 = L.marker([37.79728,
# 							-122.398436],
# 							{'icon':marker_2_icon}
# 							);
#       marker_2.bindPopup(&quot;Davis at Jackson&quot;);
#       marker_2._popup.options.maxWidth = 300;
#       map.addLayer(marker_2)
#
#       var marker_3_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_3 = L.marker([37.794231,
# 							-122.402923],
# 							{'icon':marker_3_icon}
# 							);
#       marker_3.bindPopup(&quot;Commercial at Montgomery&quot;);
#       marker_3._popup.options.maxWidth = 300;
#       map.addLayer(marker_3)
#
#       var marker_4_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_4 = L.marker([37.795425,
# 							-122.404767],
# 							{'icon':marker_4_icon}
# 							);
#       marker_4.bindPopup(&quot;Washington at Kearney&quot;);
#       marker_4._popup.options.maxWidth = 300;
#       map.addLayer(marker_4)
#
#       var marker_5_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_5 = L.marker([37.788975,
# 							-122.403452],
# 							{'icon':marker_5_icon}
# 							);
#       marker_5.bindPopup(&quot;Post at Kearney&quot;);
#       marker_5._popup.options.maxWidth = 300;
#       map.addLayer(marker_5)
#
#       var marker_6_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_6 = L.marker([37.799953,
# 							-122.398525],
# 							{'icon':marker_6_icon}
# 							);
#       marker_6.bindPopup(&quot;Embarcadero at Vallejo&quot;);
#       marker_6._popup.options.maxWidth = 300;
#       map.addLayer(marker_6)
#
#       var marker_7_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_7 = L.marker([37.790302,
# 							-122.390637],
# 							{'icon':marker_7_icon}
# 							);
#       marker_7.bindPopup(&quot;Spear at Folsom&quot;);
#       marker_7._popup.options.maxWidth = 300;
#       map.addLayer(marker_7)
#
#       var marker_8_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_8 = L.marker([37.795392,
# 							-122.394203],
# 							{'icon':marker_8_icon}
# 							);
#       marker_8.bindPopup(&quot;Harry Bridges Plaza (Ferry Building)&quot;);
#       marker_8._popup.options.maxWidth = 300;
#       map.addLayer(marker_8)
#
#       var marker_9_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_9 = L.marker([37.791464,
# 							-122.391034],
# 							{'icon':marker_9_icon}
# 							);
#       marker_9.bindPopup(&quot;Embarcadero at Folsom&quot;);
#       marker_9._popup.options.maxWidth = 300;
#       map.addLayer(marker_9)
#
#       var marker_10_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_10 = L.marker([37.783871,
# 							-122.408433],
# 							{'icon':marker_10_icon}
# 							);
#       marker_10.bindPopup(&quot;Powell Street BART&quot;);
#       marker_10._popup.options.maxWidth = 300;
#       map.addLayer(marker_10)
#
#       var marker_11_icon = L.AwesomeMarkers.icon({ icon: 'info-sign',markerColor: 'blue',prefix: 'glyphicon',extraClasses: 'fa-rotate-0'});
#       var marker_11 = L.marker([37.787152,
# 							-122.388013],
# 							{'icon':marker_11_icon}
# 							);
#       marker_11.bindPopup(&quot;Embarcadero at Bryant&quot;);
#       marker_11._popup.option

# %%
weather = Table.read_table('201508_weather_data.csv')
weather
# Out:
# PDT       | Max TemperatureF | Mean TemperatureF | Min TemperatureF | Max Dew PointF | MeanDew PointF | Min DewpointF | Max Humidity |  Mean Humidity |  Min Humidity |  Max Sea Level PressureIn |  Mean Sea Level PressureIn |  Min Sea Level PressureIn |  Max VisibilityMiles |  Mean VisibilityMiles |  Min VisibilityMiles |  Max Wind SpeedMPH |  Mean Wind SpeedMPH |  Max Gust SpeedMPH | PrecipitationIn |  CloudCover |  Events |  WindDirDegrees | Zip
# 9/1/2014  | 83               | 70                | 57               | 58             | 56             | 52            | 86           | 64             | 42            | 29.86                     | 29.82                      | 29.76                     | 10                   | 10                    | 8                    | 16                 | 7                   | 20                 | 0               | 0           | nan     | 290             | 94107
# 9/2/2014  | 72               | 66                | 60               | 58             | 57             | 55            | 84           | 73             | 61            | 29.87                     | 29.82                      | 29.79                     | 10                   | 10                    | 7                    | 21                 | 8                   | nan                | 0               | 5           | nan     | 290             | 94107
# 9/3/2014  | 76               | 69                | 61               | 57             | 56             | 55            | 84           | 69             | 53            | 29.81                     | 29.76                      | 29.72                     | 10                   | 10                    | 10                   | 21                 | 8                   | 24                 | 0               | 4           | nan     | 276             | 94107
# 9/4/2014  | 74               | 68                | 61               | 57             | 57             | 56            | 84           | 71             | 57            | 29.81                     | 29.76                      | 29.72                     | 10                   | 10                    | 8                    | 22                 | 8                   | 25                 | 0               | 5           | nan     | 301             | 94107
# 9/5/2014  | 72               | 66                | 60               | 57             | 56             | 54            | 84           | 71             | 57            | 29.92                     | 29.87                      | 29.81                     | 10                   | 9                     | 7                    | 18                 | 8                   | 32                 | 0               | 4           | nan     | 309             | 94107
# 9/6/2014  | 72               | 66                | 60               | 55             | 54             | 52            | 84           | 69             | 53            | 29.98                     | 29.93                      | 29.89                     | 10                   | 9                     | 7                    | 17                 | 9                   | 30                 | 0               | 4           | nan     | 290             | 94107
# 9/7/2014  | 72               | 66                | 60               | 54             | 53             | 45            | 78           | 66             | 53            | 29.92                     | 29.87                      | 29.82                     | 10                   | 10                    | 10                   | 18                 | 10                  | 28                 | 0               | 3           | nan     | 293             | 94107
# 9/8/2014  | 68               | 64                | 59               | 52             | 51             | 50            | 72           | 64             | 55            | 29.96                     | 29.9                       | 29.86                     | 10                   | 10                    | 10                   | 18                 | 12                  | 22                 | 0               | 4           | nan     | 272             | 94107
# 9/9/2014  | 72               | 65                | 57               | 56             | 53             | 52            | 87           | 72             | 57            | 30.01                     | 29.96                      | 29.91                     | 10                   | 10                    | 10                   | 17                 | 7                   | 21                 | 0               | 5           | nan     | 270             | 94107
# 9/10/2014 | 82               | 68                | 54               | 59             | 56             | 51            | 93           | 66             | 39            | 29.96                     | 29.9                       | 29.83                     | 10                   | 9                     | 5                    | 16                 | 5                   | 20                 | 0               | 1           | nan     | 283             | 94107
# ... (1815 rows omitted)

# %%
temp = weather.where('Zip', 94107).select([0, 1]).sort(1)
temp
# Out:
# PDT        | Max TemperatureF
# 1/2/2015   | 50
# 1/3/2015   | 53
# 1/4/2015   | 54
# 12/27/2014 | 55
# 12/28/2014 | 55
# 12/29/2014 | 55
# 12/30/2014 | 55
# 12/12/2014 | 56
# 12/15/2014 | 56
# 1/1/2015   | 56
# ... (355 rows omitted)

# %%
temp = temp.relabeled(0, 'Date').relabeled(1, 'Temp')
temp
# Out:
# Date       | Temp
# 1/2/2015   | 50
# 1/3/2015   | 53
# 1/4/2015   | 54
# 12/27/2014 | 55
# 12/28/2014 | 55
# 12/29/2014 | 55
# 12/30/2014 | 55
# 12/12/2014 | 56
# 12/15/2014 | 56
# 1/1/2015   | 56
# ... (355 rows omitted)

# %%
trips.column(2)
# Out:
# array(['8/31/2015 23:26', '8/31/2015 23:11', '8/31/2015 23:13', ...,
#        '9/1/2014 0:05', '9/1/2014 0:05', '9/1/2014 0:05'], dtype=object)

# %%
'8/31/2015 23:26'.split()
# Out:
# ['8/31/2015', '23:26']

# %%
np.array('8/31/2015 23:26'.split()).item(0)
# Out:
# '8/31/2015'

# %%
def day(time):
    return np.array(time.split()).item(0)

dates = trips.apply(day, 2)
dates
# Out:
# array(['8/31/2015', '8/31/2015', '8/31/2015', ..., '9/1/2014', '9/1/2014',
#        '9/1/2014'],
#       dtype='<U10')

# %%
trip_dates = trips.select('Start Station').with_column('Date', dates)
trip_dates
# Out:
# Start Station                                 | Date
# Harry Bridges Plaza (Ferry Building)          | 8/31/2015
# San Antonio Shopping Center                   | 8/31/2015
# Post at Kearny                                | 8/31/2015
# San Jose City Hall                            | 8/31/2015
# Embarcadero at Folsom                         | 8/31/2015
# Yerba Buena Center of the Arts (3rd @ Howard) | 8/31/2015
# Embarcadero at Folsom                         | 8/31/2015
# Embarcadero at Sansome                        | 8/31/2015
# Beale at Market                               | 8/31/2015
# Post at Kearny                                | 8/31/2015
# ... (354142 rows omitted)

# %%
by_date = trip_dates.group('Date').sort(1)
by_date
# Out:
# Date       | count
# 12/11/2014 | 107
# 11/30/2014 | 121
# 11/27/2014 | 133
# 2/8/2015   | 141
# 12/25/2014 | 150
# 1/1/2015   | 181
# 1/4/2015   | 206
# 4/5/2015   | 216
# 12/27/2014 | 231
# 11/23/2014 | 235
# ... (355 rows omitted)

# %%
by_date = by_date.relabeled(1, 'Trips')
by_date
# Out:
# Date       | Trips
# 12/11/2014 | 107
# 11/30/2014 | 121
# 11/27/2014 | 133
# 2/8/2015   | 141
# 12/25/2014 | 150
# 1/1/2015   | 181
# 1/4/2015   | 206
# 4/5/2015   | 216
# 12/27/2014 | 231
# 11/23/2014 | 235
# ... (355 rows omitted)

# %% [markdown]
# ## Join

# %%
both = by_date.join('Date', temp)
both
# Out:
# Date      | Trips | Temp
# 1/1/2015  | 181   | 56
# 1/10/2015 | 362   | 60
# 1/11/2015 | 327   | 57
# 1/12/2015 | 1344  | 57
# 1/13/2015 | 1368  | 66
# 1/14/2015 | 1296  | 59
# 1/15/2015 | 1229  | 59
# 1/16/2015 | 1082  | 57
# 1/17/2015 | 319   | 57
# 1/18/2015 | 275   | 65
# ... (355 rows omitted)

# %%
np.average(both.where(both.column('Temp') < 65).column('Trips'))
# Out:
# 847.41525423728808

# %%
np.average(both.where(both.column('Temp') >= 65).column('Trips'))
# Out:
# 1028.9757085020242

# %% [markdown]
# ## Pivot

# %%
set(weather.column(' Events'))
# Out:
# {nan, 'Fog', 'Fog-Rain', 'Rain-Thunderstorm', 'Rain'}

# %%
def raining(event):
    if event == 'Rain' or event == 'Fog-Rain' or event == 'Rain-Thunderstorm':
        return 'Wet'
    else:
        return 'Dry'
    
def temperature(k):
    if k >= 65:
        return "Hot"
    else:
        return "Cold"
    
climate = Table().with_columns([
        'Date', weather.column(0),
        'Rain', weather.apply(raining, ' Events'),
        'Temp', weather.apply(temperature, 'Max TemperatureF'),
    ])

climate
# Out:
# Date      | Rain | Temp
# 9/1/2014  | Dry  | Hot
# 9/2/2014  | Dry  | Hot
# 9/3/2014  | Dry  | Hot
# 9/4/2014  | Dry  | Hot
# 9/5/2014  | Dry  | Hot
# 9/6/2014  | Dry  | Hot
# 9/7/2014  | Dry  | Hot
# 9/8/2014  | Dry  | Hot
# 9/9/2014  | Dry  | Hot
# 9/10/2014 | Dry  | Hot
# ... (1815 rows omitted)

# %%
by_date.join('Date', climate).pivot('Rain', 'Temp', 'Trips', np.average)
# Out:
# Temp | Dry Trips | Wet Trips
# Cold | 925.563   | 628.097
# Hot  | 1022.26   | 1083.67
